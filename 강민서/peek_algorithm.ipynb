# %%
import pandas as pd

f = pd.read_csv('C:/Users/Alstromeria/Desktop/Data210803162434.csv')
#ax(g)
df = pd.DataFrame(f.values[700:1000,2])
df = df.astype(float)
print(df.loc[0])
df.plot()
# Out:
# 0   -0.1758
# Name: 0, dtype: float64
# <AxesSubplot:>

# %%
df1=pd.DataFrame(f.values[700:750,2])
df3= df1.astype(float)
df3.plot()

df1 = df1.rename_axis('index').reset_index()
df1.columns=['index', 'value']

print(df1['value'].values.max())
a=df1['value']==df1['value'].values.max()
print(df1[a])
# Out:
# 4.0815
#     index   value
# 43     43  4.0815

# %%
df2 = pd.DataFrame(index=range(0), columns=['index', 'value'])
df2=df2.append(df1[a])
df2=df2.append({'index':40, 'value':4.0800},ignore_index=True)
print(df2)

#df2 = df2['value'].astype(float)

df2=df2.astype({'index':int, 'value':float})
df3=df2.plot.scatter(x='index',y='value')
# Out:
#   index   value
# 0    43  4.0815
# 1  40.0    4.08

# %%
f = pd.read_csv('C:/Users/Alstromeria/Desktop/Data210803162434.csv')
#ax(g)
df = pd.DataFrame(f.values[700:1000,2])
df = df.astype(float)
df.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

f = pd.read_csv('C:/Users/Alstromeria/Desktop/Data210803162434.csv')
#ay(g)
print(df)
df = pd.DataFrame(f.values[700:1000,3])
df = df.astype(float)
df.plot()
# Out:
#           0
# 0   -0.1758
# 1   -0.1841
# 2   -0.2290
# 3   -0.2212
# 4   -0.2051
# ..      ...
# 295  0.0708
# 296  0.0576
# 297  0.0171
# 298 -0.0547
# 299 -0.0327
#
# [300 rows x 1 columns]
# <AxesSubplot:>

# %%
import pandas as pd

f = pd.read_csv('C:/Users/Alstromeria/Desktop/Data210803162434.csv')
#az(g)
df = pd.DataFrame(f.values[700:1000,4])
df = df.astype(float)
df.plot()
# Out:
# <AxesSubplot:>
